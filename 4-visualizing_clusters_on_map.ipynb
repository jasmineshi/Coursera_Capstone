# %% [markdown]
# # Part 4: Visualizing Clusters on Map
# In this stage, I will visualize cluster results by color coding and labeling the neighborhoods on a map

# %%
import pandas as pd
import numpy as np
import folium
from geopy.geocoders import Nominatim

# %%
# import police dataset with cluster results
pol_df = pd.read_csv('./data/pol_clus_df.csv', encoding = "ISO-8859-1")

#set neighborhood as index
pol_df.set_index(pol_df['Neighborhood'], drop=True, inplace=True)
pol_df.drop(['Neighborhood'], axis=1, inplace=True)

#check shape and format
print(pol_df.shape)
pol_df.head()
# Out:
# (73, 8)
#                                Sex Offences  Assaults   Robbery  \
# Neighborhood
# VPD Arbutus Ridge                  0.009524  0.003778  0.001608
# VPD Central_Business_District      0.316190  0.404222  0.414791
# VPD Dunbar-Southlands              0.011429  0.003556  0.003215
# VPD Fairview                       0.049524  0.026444  0.020900
# VPD Grandview-Woodland             0.059048  0.052444  0.056270
#
#                                Break & Enter  Auto Theft  Other Theft  \
# Neighborhood
# VPD Arbutus Ridge                   0.016613    0.009393     0.006241
# VPD Central_Business_District       0.169968    0.133671     0.372350
# VPD Dunbar-Southlands               0.018104    0.009393     0.008954
# VPD Fairview                        0.067519    0.034682     0.060001
# VPD Grandview-Woodland              0.062194    0.088150     0.040634
#
#                                Offensive Weapons  Cluster Labels
# Neighborhood
# VPD Arbutus Ridge                       0.000000               5
# VPD Central_Business_District           0.537123               3
# VPD Dunbar-Southlands                   0.002320               5
# VPD Fairview                            0.019722               1
# VPD Grandview-Woodland                  0.024362               1

# %% [markdown]
# 🤑 __Get addresses of neighborhoods__ <br>
# In order to plot neighborhoods on a map, we first need to obtain the addresses of each neighborhood.
#
# I have already obtained the addresses manually and stored it in a csv file. Here is how I obtained them:
# - for Vancouver, I used the neighborhood name as address since it was not numbered like the others
# - Toronto and Montreal both have numbered neighborhood names due to the naming convention of the police department. I searched up the address of the police station at each neighborhood and used that as the address.

# %%
# load addresses data
add_df = pd.read_csv("./data/all addresses.csv", header=None)

print(add_df.shape)
add_df.head()
# Out:
# (73, 2)
#                            0                                    1
# 0             Arbutus Ridge           Arbutus Ridge Vancouver, BC
# 1  Central_Business_District  Vancouver City Center Vancouver, BC
# 2          Dunbar-Southlands      Dunbar-Southlands Vancouver, BC
# 3                   Fairview               Fairview Vancouver, BC
# 4         Grandview-Woodland     Grandview-Woodland Vancouver, BC

# %%
# set index the same as that of pol_df
add_df.set_index(pol_df.index, drop=True, inplace=True)
add_df
# Out:
#                                                        0  \
# Neighborhood
# VPD Arbutus Ridge                         Arbutus Ridge
# VPD Central_Business_District  Central_Business_District
# VPD Dunbar-Southlands                  Dunbar-Southlands
# VPD Fairview                                    Fairview
# VPD Grandview-Woodland                Grandview-Woodland
# ...                                                  ...
# SPVM 42.0                                             42
# SPVM 45.0                                             45
# SPVM 46.0                                             46
# SPVM 48.0                                             48
# SPVM 49.0                                             49
#
#                                                                                1
# Neighborhood
# VPD Arbutus Ridge                                    Arbutus Ridge Vancouver, BC
# VPD Central_Business_District                Vancouver City Center Vancouver, BC
# VPD Dunbar-Southlands                            Dunbar-Southlands Vancouver, BC
# VPD Fairview                                              Fairview Vancouver, BC
# VPD Grandview-Woodland                          Grandview-Woodland Vancouver, BC
# ...                                                                          ...
# SPVM 42.0                           8181 Boulevard Lacordaire, Saint-Léonard, QC
# SPVM 45.0                         8200 Boulevard Maurice-Duplessis, Montréal, QC
# SPVM 46.0                      6850, boulevard Joseph-Renaud, Anjou, Montréal...
# SPVM 48.0                                    6680 Rue Sherbrooke E, Montréal, QC
# SPVM 49.0                       1498 Boulevard Saint-Jean-Baptiste, Montréal, QC
#
# [73 rows x 2 columns]

# %%
# only keep column 1, which is the address column
add_df = add_df[[1]]
add_df.columns = ['Address']
add_df.head()
# Out:
#                                                            Address
# Neighborhood
# VPD Arbutus Ridge                      Arbutus Ridge Vancouver, BC
# VPD Central_Business_District  Vancouver City Center Vancouver, BC
# VPD Dunbar-Southlands              Dunbar-Southlands Vancouver, BC
# VPD Fairview                                Fairview Vancouver, BC
# VPD Grandview-Woodland            Grandview-Woodland Vancouver, BC

# %% [markdown]
# 🤑 __Get latitude and longitude from address__<br>
# Need to convert addresses into longitude and latitude in order to input them into the plotting function. We will do this using the Geopy package

# %%
# get lat and long
lat = []
long = []
geolocator = Nominatim(user_agent='neigh_explorer') # create object instance for obtaining lat and long from address
for address in add_df['Address'].tolist(): # loop through every address 
    loc = geolocator.geocode(address, country_codes='ca')
    if loc==None: # just in case some addresses aren't recognized, we need to know so we can fix them
        print(address)
    else:
        lat.append(loc.latitude)
        long.append(loc.longitude)

# %%
# create new columns latitude and longitude in the address dataframe
add_df['Latitude'] = lat
add_df['Longitude'] = long
add_df.head()
# Out:
#                                                            Address   Latitude  \
# Neighborhood
# VPD Arbutus Ridge                      Arbutus Ridge Vancouver, BC  49.246305
# VPD Central_Business_District  Vancouver City Center Vancouver, BC  49.282471
# VPD Dunbar-Southlands              Dunbar-Southlands Vancouver, BC  49.237864
# VPD Fairview                                Fairview Vancouver, BC  49.261956
# VPD Grandview-Woodland            Grandview-Woodland Vancouver, BC  49.275849
#
#                                 Longitude
# Neighborhood
# VPD Arbutus Ridge             -123.159636
# VPD Central_Business_District -123.118628
# VPD Dunbar-Southlands         -123.184354
# VPD Fairview                  -123.130408
# VPD Grandview-Woodland        -123.066934

# %%
# merge address dataframe with crime dataframe
A = pol_df
B = add_df
premium_pol_df = pd.merge(A, B, left_index=True, right_index=True)
premium_pol_df.head()
# Out:
#                                Sex Offences  Assaults   Robbery  \
# Neighborhood
# VPD Arbutus Ridge                  0.009524  0.003778  0.001608
# VPD Central_Business_District      0.316190  0.404222  0.414791
# VPD Dunbar-Southlands              0.011429  0.003556  0.003215
# VPD Fairview                       0.049524  0.026444  0.020900
# VPD Grandview-Woodland             0.059048  0.052444  0.056270
#
#                                Break & Enter  Auto Theft  Other Theft  \
# Neighborhood
# VPD Arbutus Ridge                   0.016613    0.009393     0.006241
# VPD Central_Business_District       0.169968    0.133671     0.372350
# VPD Dunbar-Southlands               0.018104    0.009393     0.008954
# VPD Fairview                        0.067519    0.034682     0.060001
# VPD Grandview-Woodland              0.062194    0.088150     0.040634
#
#                                Offensive Weapons  Cluster Labels  \
# Neighborhood
# VPD Arbutus Ridge                       0.000000               5
# VPD Central_Business_District           0.537123               3
# VPD Dunbar-Southlands                   0.002320               5
# VPD Fairview                            0.019722               1
# VPD Grandview-Woodland                  0.024362               1
#
#                                                            Address   Latitude  \
# Neighborhood
# VPD Arbutus Ridge                      Arbutus Ridge Vancouver, BC  49.246305
# VPD Central_Business_District  Vancouver City Center Vancouver, BC  49.282471
# VPD Dunbar-Southlands              Dunbar-Southlands Vancouver, BC  49.237864
# VPD Fairview                                Fairview Vancouver, BC  49.261956
# VPD Grandview-Woodland            Grandview-Woodland Vancouver, BC  49.275849
#
#                                 Longitude
# Neighborhood
# VPD Arbutus Ridge             -123.159636
# VPD Central_Business_District -123.118628
# VPD Dunbar-Southlands         -123.184354
# VPD Fairview                  -123.130408
# VPD Grandview-Woodland        -123.066934

# %% [markdown]
# 🤑 __Separate the cities in the dataframe__ <br>
# I want to plot three different maps, one for each city. Thus we need one dataframe for each city.

# %%
# find the index of the respective cities and separate accordingly

# boolean list for each city
vpd = []
tps = []
spvm = []

# iterate through neighborhood names to see which city it belongs to
for neigh in premium_pol_df.index: 
    vpd.append('VPD' in neigh)
    tps.append('TPS' in neigh)
    spvm.append('SPVM' in neigh)
    
# create separate dataframes
vpd_df = premium_pol_df[vpd]
tps_df = premium_pol_df[tps]
spvm_df = premium_pol_df[spvm]

# %%
# check shape of the dataframes
print(vpd_df.shape)
print(tps_df.shape)
print(spvm_df.shape)
# Out:
# (24, 11)
# (16, 11)
# (33, 11)

# %% [markdown]
# looks right :)

# %% [markdown]
# 🤑 __Plot the maps!__ <br>
# I will be using the folium package which creates interactive maps with markers

# %%
# Vancouver first
# get the coordinates for the city
geolocator = Nominatim(user_agent='neigh_explorer')
van = geolocator.geocode('Vancouver', country_codes='ca')

# %%
# define color and label for each cluster 
color_dictionary = {5:'#FFC300', 6:'#FF5733', 1:'#C70039', 2:'#900C3F', 0:'#581845', 4:'#FDFEFE', 3:'#FDFEFE'}
label_dictionary = {5:'very low crime', 6:'low crime', 1:'medium crime', 2:'high crime', 0:'very high crime', 
                    4:'OUTLIER: very low in all except offensive weapons',
                    3:'OUTLIER: exceptionally high crime'}
line_color = '#1C2833'

# %%
# plot map for vancouver
van_map_clusters = folium.Map(location=[van.latitude, van.longitude], zoom_start=12) #initialize map

for lat, long, neigh, clus in zip(vpd_df['Latitude'], vpd_df['Longitude'], vpd_df.index, vpd_df['Cluster Labels']):
    # create marker for each neighborhood and add to map
    folium.CircleMarker(location=[lat, long], 
                        radius=10, 
                        popup=label_dictionary[clus]+'. ' +neigh, 
                        fill=True,
                        fill_opacity=1,
                        fill_color=color_dictionary[clus],
                        color=line_color).add_to(van_map_clusters)
    
van_map_clusters
# click on the markers to see the labels!
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_52329950c912482b8d316cf9f19c1f8a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_52329950c912482b8d316cf9f19c1f8a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_52329950c912482b8d316cf9f19c1f8a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_52329950c912482b8d316cf9f19c1f8a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B49.2608724%2C%20-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# Toronto next
# Toronto coordinates
geolocator = Nominatim(user_agent='neigh_explorer')
tor = geolocator.geocode('Toronto', country_codes='ca')

# %%
tor_map_clusters = folium.Map(location=[tor.latitude, tor.longitude], zoom_start=11)

for lat, long, neigh, clus in zip(tps_df['Latitude'], tps_df['Longitude'], tps_df.index, tps_df['Cluster Labels']):
    
    folium.CircleMarker(location=[lat, long], 
                        radius=10, 
                        popup=label_dictionary[clus]+'. ' +neigh, 
                        fill=True,
                        fill_opacity=1,
                        fill_color=color_dictionary[clus],
                        color=line_color).add_to(tor_map_clusters)
    
tor_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3d4771a2d2f1404586658f6e291a65cf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3d4771a2d2f1404586658f6e291a65cf%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3d4771a2d2f1404586658f6e291a65cf%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3d4771a2d2f1404586658f6e291a65cf%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# last but not least, montreal
# Montreal coordinates
geolocator = Nominatim(user_agent='neigh_explorer')
mon = geolocator.geocode('Montreal', country_codes='ca')

# %%
mon_map_clusters = folium.Map(location=[mon.latitude, mon.longitude], zoom_start=11)

for lat, long, neigh, clus in zip(spvm_df['Latitude'], spvm_df['Longitude'], spvm_df.index, spvm_df['Cluster Labels']):
    
    folium.CircleMarker(location=[lat, long], 
                        radius=10, 
                        popup=label_dictionary[clus]+'. ' +neigh, 
                        fill=True,
                        fill_opacity=1,
                        fill_color=color_dictionary[clus],
                        color=line_color).add_to(mon_map_clusters)
    
mon_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_495a8faf3cba4db8a8fa2327e2fe3441%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_495a8faf3cba4db8a8fa2327e2fe3441%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_495a8faf3cba4db8a8fa2327e2fe3441%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_495a8faf3cba4db8a8fa2327e2fe3441%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B45.4972159%2C%20-73.6103642%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
